# %%
import numpy as np
import pandas as pd
import json

# %%
# Đường dẫn của data
file_name = r'D:\Learning\ML\BTL\data.json'

# %%
# Hàm flatten dict
def flatten_data(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
# Mở file
with open(file_name, 'r', encoding='utf-8') as file:
    data = json.load(file)

# %% [markdown]
# ### 1. Chênh lệch Lượng vàng chênh lệch giữa xanh và đỏ mỗi phút

# %%
# Hàm tính lượng vàng chênh lệch giữa đội xanh và đỏ mỗi phút
def get_gold_difference_between_blue_and_red_team_per_minute(data):
    gold_difference_df = {}
    for minute, frame in enumerate(data['info']['frames'], start=0):
        total_gold_blue = 0
        total_gold_red = 0
        for participant_id, data in frame["participantFrames"].items():
            participant_id = int(participant_id)
            total_gold = data["totalGold"]
            
            if 1 <= participant_id <= 5:
                total_gold_blue += total_gold
            elif 6 <= participant_id <= 10:
                total_gold_red += total_gold
        gold_difference_df[f"gold_difference_at_{minute}"] = total_gold_blue - total_gold_red
    return gold_difference_df

# %%
# Dict Lượng vàng chênh lệch giữa xanh và đỏ mỗi phút
gold_difference_df = get_gold_difference_between_blue_and_red_team_per_minute(data)
gold_difference_df
# Out:
# {'gold_difference_at_0': 0,
#  'gold_difference_at_1': 0,
#  'gold_difference_at_2': -62,
#  'gold_difference_at_3': 882,
#  'gold_difference_at_4': 860,
#  'gold_difference_at_5': 873,
#  'gold_difference_at_6': 626,
#  'gold_difference_at_7': -530,
#  'gold_difference_at_8': -391,
#  'gold_difference_at_9': -324,
#  'gold_difference_at_10': 250,
#  'gold_difference_at_11': 817,
#  'gold_difference_at_12': -942,
#  'gold_difference_at_13': -648,
#  'gold_difference_at_14': -394,
#  'gold_difference_at_15': 481,
#  'gold_difference_at_16': 952,
#  'gold_difference_at_17': -237,
#  'gold_difference_at_18': 1241,
#  'gold_difference_at_19': 3676,
#  'gold_difference_at_20': 3956,
#  'gold_difference_at_21': 2470,
#  'gold_difference_at_22': 2574,
#  'gold_difference_at_23': 1554,
#  'gold_difference_at_24': 1833,
#  'gold_difference_at_25': 1054,
#  'gold_difference_at_26': -62,
#  'gold_difference_at_27': -2711,
#  'gold_difference_at_28': -2418,
#  'gold_difference_at_29': -3631,
#  'gold_difference_at_30': -5268,
#  'gold_difference_at_31': -4369,
#  'gold_difference_at_32': -4033,
#  'gold_difference_at_33': -3800,
#  'gold_difference_at_34': -4996,
#  'gold_difference_at_35': -7979}

# %% [markdown]
# ### 2. Trạng thái trụ mỗi đội, mỗi loại, mỗi phút

# %%
# Hàm trạng thái trụ mỗi đội, mỗi loại, mỗi phút
def calculate_turret_status(data):
    initial_turrets = {
        "blue": {
            "MID_LANE": {"INNER_TURRET": 1, "OUTER_TURRET": 1, "BASE_TURRET": 1, "NEXUS_TURRET": 2},
            "TOP_LANE": {"INNER_TURRET": 1, "OUTER_TURRET": 1, "BASE_TURRET": 1},
            "BOT_LANE": {"INNER_TURRET": 1, "OUTER_TURRET": 1, "BASE_TURRET": 1},
        },
        "red": {
            "MID_LANE": {"INNER_TURRET": 1, "OUTER_TURRET": 1, "BASE_TURRET": 1, "NEXUS_TURRET": 2},
            "TOP_LANE": {"INNER_TURRET": 1, "OUTER_TURRET": 1, "BASE_TURRET": 1},
            "BOT_LANE": {"INNER_TURRET": 1, "OUTER_TURRET": 1, "BASE_TURRET": 1},
        }
    }

    # Kết quả lưu trạng thái trụ theo từng phút
    turret_status = {}

    # Lấy danh sách các frame (tương ứng phút)
    frames = data.get("info", {}).get("frames", [])

    # Duyệt qua từng frame (mỗi frame là 1 phút)
    for frame_index, frame in enumerate(frames):
        minute = frame_index

        # Duyệt qua các lane và các loại trụ để sao chép trạng thái ban đầu cho phút đầu tiên
        for team in ["blue", "red"]:
            for lane, turrets in initial_turrets[team].items():
                for tower_type, count in turrets.items():
                    # Cập nhật trạng thái trụ cho phút hiện tại
                    key = f"{team}_{lane}_{tower_type}_at_{minute}"
                    turret_status[key] = count

        # Lấy danh sách sự kiện trong frame
        events = frame.get("events", [])
        for event in events:
            # Kiểm tra nếu sự kiện là phá hủy trụ
            if event.get("type") == "BUILDING_KILL" and event.get("towerType") and event.get("laneType"):
                team_id = event.get("teamId")
                tower_type = event.get("towerType")
                lane_type = event.get("laneType")

                # Xác định đội (100 = blue, 200 = red)
                team = "blue" if team_id == 100 else "red"

                # Xác định key cho trụ bị phá hủy
                key = f"{team}_{lane_type}_{tower_type}_at_{minute}"

                # Giảm số lượng trụ trong lane và loại trụ tương ứng
                if key in turret_status:
                    turret_status[key] -= 1
                    initial_turrets[team][lane_type][tower_type] -= 1

    return turret_status

# %%
# Dict trạng thái trụ mỗi đội, mỗi loại, mỗi phút
remaining_turret_df = calculate_turret_status(data)
remaining_turret_df
# Out:
# {'blue_MID_LANE_INNER_TURRET_at_0': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_0': 1,
#  'blue_MID_LANE_BASE_TURRET_at_0': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_0': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_0': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_0': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_0': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_0': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_0': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_0': 1,
#  'red_MID_LANE_INNER_TURRET_at_0': 1,
#  'red_MID_LANE_OUTER_TURRET_at_0': 1,
#  'red_MID_LANE_BASE_TURRET_at_0': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_0': 2,
#  'red_TOP_LANE_INNER_TURRET_at_0': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_0': 1,
#  'red_TOP_LANE_BASE_TURRET_at_0': 1,
#  'red_BOT_LANE_INNER_TURRET_at_0': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_0': 1,
#  'red_BOT_LANE_BASE_TURRET_at_0': 1,
#  'blue_MID_LANE_INNER_TURRET_at_1': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_1': 1,
#  'blue_MID_LANE_BASE_TURRET_at_1': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_1': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_1': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_1': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_1': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_1': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_1': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_1': 1,
#  'red_MID_LANE_INNER_TURRET_at_1': 1,
#  'red_MID_LANE_OUTER_TURRET_at_1': 1,
#  'red_MID_LANE_BASE_TURRET_at_1': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_1': 2,
#  'red_TOP_LANE_INNER_TURRET_at_1': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_1': 1,
#  'red_TOP_LANE_BASE_TURRET_at_1': 1,
#  'red_BOT_LANE_INNER_TURRET_at_1': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_1': 1,
#  'red_BOT_LANE_BASE_TURRET_at_1': 1,
#  'blue_MID_LANE_INNER_TURRET_at_2': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_2': 1,
#  'blue_MID_LANE_BASE_TURRET_at_2': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_2': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_2': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_2': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_2': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_2': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_2': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_2': 1,
#  'red_MID_LANE_INNER_TURRET_at_2': 1,
#  'red_MID_LANE_OUTER_TURRET_at_2': 1,
#  'red_MID_LANE_BASE_TURRET_at_2': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_2': 2,
#  'red_TOP_LANE_INNER_TURRET_at_2': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_2': 1,
#  'red_TOP_LANE_BASE_TURRET_at_2': 1,
#  'red_BOT_LANE_INNER_TURRET_at_2': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_2': 1,
#  'red_BOT_LANE_BASE_TURRET_at_2': 1,
#  'blue_MID_LANE_INNER_TURRET_at_3': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_3': 1,
#  'blue_MID_LANE_BASE_TURRET_at_3': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_3': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_3': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_3': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_3': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_3': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_3': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_3': 1,
#  'red_MID_LANE_INNER_TURRET_at_3': 1,
#  'red_MID_LANE_OUTER_TURRET_at_3': 1,
#  'red_MID_LANE_BASE_TURRET_at_3': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_3': 2,
#  'red_TOP_LANE_INNER_TURRET_at_3': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_3': 1,
#  'red_TOP_LANE_BASE_TURRET_at_3': 1,
#  'red_BOT_LANE_INNER_TURRET_at_3': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_3': 1,
#  'red_BOT_LANE_BASE_TURRET_at_3': 1,
#  'blue_MID_LANE_INNER_TURRET_at_4': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_4': 1,
#  'blue_MID_LANE_BASE_TURRET_at_4': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_4': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_4': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_4': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_4': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_4': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_4': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_4': 1,
#  'red_MID_LANE_INNER_TURRET_at_4': 1,
#  'red_MID_LANE_OUTER_TURRET_at_4': 1,
#  'red_MID_LANE_BASE_TURRET_at_4': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_4': 2,
#  'red_TOP_LANE_INNER_TURRET_at_4': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_4': 1,
#  'red_TOP_LANE_BASE_TURRET_at_4': 1,
#  'red_BOT_LANE_INNER_TURRET_at_4': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_4': 1,
#  'red_BOT_LANE_BASE_TURRET_at_4': 1,
#  'blue_MID_LANE_INNER_TURRET_at_5': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_5': 1,
#  'blue_MID_LANE_BASE_TURRET_at_5': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_5': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_5': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_5': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_5': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_5': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_5': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_5': 1,
#  'red_MID_LANE_INNER_TURRET_at_5': 1,
#  'red_MID_LANE_OUTER_TURRET_at_5': 1,
#  'red_MID_LANE_BASE_TURRET_at_5': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_5': 2,
#  'red_TOP_LANE_INNER_TURRET_at_5': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_5': 1,
#  'red_TOP_LANE_BASE_TURRET_at_5': 1,
#  'red_BOT_LANE_INNER_TURRET_at_5': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_5': 1,
#  'red_BOT_LANE_BASE_TURRET_at_5': 1,
#  'blue_MID_LANE_INNER_TURRET_at_6': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_6': 1,
#  'blue_MID_LANE_BASE_TURRET_at_6': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_6': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_6': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_6': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_6': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_6': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_6': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_6': 1,
#  'red_MID_LANE_INNER_TURRET_at_6': 1,
#  'red_MID_LANE_OUTER_TURRET_at_6': 1,
#  'red_MID_LANE_BASE_TURRET_at_6': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_6': 2,
#  'red_TOP_LANE_INNER_TURRET_at_6': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_6': 1,
#  'red_TOP_LANE_BASE_TURRET_at_6': 1,
#  'red_BOT_LANE_INNER_TURRET_at_6': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_6': 1,
#  'red_BOT_LANE_BASE_TURRET_at_6': 1,
#  'blue_MID_LANE_INNER_TURRET_at_7': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_7': 1,
#  'blue_MID_LANE_BASE_TURRET_at_7': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_7': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_7': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_7': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_7': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_7': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_7': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_7': 1,
#  'red_MID_LANE_INNER_TURRET_at_7': 1,
#  'red_MID_LANE_OUTER_TURRET_at_7': 1,
#  'red_MID_LANE_BASE_TURRET_at_7': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_7': 2,
#  'red_TOP_LANE_INNER_TURRET_at_7': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_7': 1,
#  'red_TOP_LANE_BASE_TURRET_at_7': 1,
#  'red_BOT_LANE_INNER_TURRET_at_7': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_7': 1,
#  'red_BOT_LANE_BASE_TURRET_at_7': 1,
#  'blue_MID_LANE_INNER_TURRET_at_8': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_8': 1,
#  'blue_MID_LANE_BASE_TURRET_at_8': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_8': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_8': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_8': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_8': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_8': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_8': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_8': 1,
#  'red_MID_LANE_INNER_TURRET_at_8': 1,
#  'red_MID_LANE_OUTER_TURRET_at_8': 1,
#  'red_MID_LANE_BASE_TURRET_at_8': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_8': 2,
#  'red_TOP_LANE_INNER_TURRET_at_8': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_8': 1,
#  'red_TOP_LANE_BASE_TURRET_at_8': 1,
#  'red_BOT_LANE_INNER_TURRET_at_8': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_8': 1,
#  'red_BOT_LANE_BASE_TURRET_at_8': 1,
#  'blue_MID_LANE_INNER_TURRET_at_9': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_9': 1,
#  'blue_MID_LANE_BASE_TURRET_at_9': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_9': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_9': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_9': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_9': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_9': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_9': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_9': 1,
#  'red_MID_LANE_INNER_TURRET_at_9': 1,
#  'red_MID_LANE_OUTER_TURRET_at_9': 1,
#  'red_MID_LANE_BASE_TURRET_at_9': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_9': 2,
#  'red_TOP_LANE_INNER_TURRET_at_9': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_9': 1,
#  'red_TOP_LANE_BASE_TURRET_at_9': 1,
#  'red_BOT_LANE_INNER_TURRET_at_9': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_9': 1,
#  'red_BOT_LANE_BASE_TURRET_at_9': 1,
#  'blue_MID_LANE_INNER_TURRET_at_10': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_10': 1,
#  'blue_MID_LANE_BASE_TURRET_at_10': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_10': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_10': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_10': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_10': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_10': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_10': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_10': 1,
#  'red_MID_LANE_INNER_TURRET_at_10': 1,
#  'red_MID_LANE_OUTER_TURRET_at_10': 1,
#  'red_MID_LANE_BASE_TURRET_at_10': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_10': 2,
#  'red_TOP_LANE_INNER_TURRET_at_10': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_10': 1,
#  'red_TOP_LANE_BASE_TURRET_at_10': 1,
#  'red_BOT_LANE_INNER_TURRET_at_10': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_10': 1,
#  'red_BOT_LANE_BASE_TURRET_at_10': 1,
#  'blue_MID_LANE_INNER_TURRET_at_11': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_11': 1,
#  'blue_MID_LANE_BASE_TURRET_at_11': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_11': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_11': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_11': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_11': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_11': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_11': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_11': 1,
#  'red_MID_LANE_INNER_TURRET_at_11': 1,
#  'red_MID_LANE_OUTER_TURRET_at_11': 1,
#  'red_MID_LANE_BASE_TURRET_at_11': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_11': 2,
#  'red_TOP_LANE_INNER_TURRET_at_11': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_11': 1,
#  'red_TOP_LANE_BASE_TURRET_at_11': 1,
#  'red_BOT_LANE_INNER_TURRET_at_11': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_11': 1,
#  'red_BOT_LANE_BASE_TURRET_at_11': 1,
#  'blue_MID_LANE_INNER_TURRET_at_12': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_12': 1,
#  'blue_MID_LANE_BASE_TURRET_at_12': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_12': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_12': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_12': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_12': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_12': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_12': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_12': 1,
#  'red_MID_LANE_INNER_TURRET_at_12': 1,
#  'red_MID_LANE_OUTER_TURRET_at_12': 1,
#  'red_MID_LANE_BASE_TURRET_at_12': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_12': 2,
#  'red_TOP_LANE_INNER_TURRET_at_12': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_12': 1,
#  'red_TOP_LANE_BASE_TURRET_at_12': 1,
#  'red_BOT_LANE_INNER_TURRET_at_12': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_12': 1,
#  'red_BOT_LANE_BASE_TURRET_at_12': 1,
#  'blue_MID_LANE_INNER_TURRET_at_13': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_13': 1,
#  'blue_MID_LANE_BASE_TURRET_at_13': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_13': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_13': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_13': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_13': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_13': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_13': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_13': 1,
#  'red_MID_LANE_INNER_TURRET_at_13': 1,
#  'red_MID_LANE_OUTER_TURRET_at_13': 1,
#  'red_MID_LANE_BASE_TURRET_at_13': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_13': 2,
#  'red_TOP_LANE_INNER_TURRET_at_13': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_13': 1,
#  'red_TOP_LANE_BASE_TURRET_at_13': 1,
#  'red_BOT_LANE_INNER_TURRET_at_13': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_13': 1,
#  'red_BOT_LANE_BASE_TURRET_at_13': 1,
#  'blue_MID_LANE_INNER_TURRET_at_14': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_14': 1,
#  'blue_MID_LANE_BASE_TURRET_at_14': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_14': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_14': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_14': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_14': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_14': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_14': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_14': 1,
#  'red_MID_LANE_INNER_TURRET_at_14': 1,
#  'red_MID_LANE_OUTER_TURRET_at_14': 1,
#  'red_MID_LANE_BASE_TURRET_at_14': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_14': 2,
#  'red_TOP_LANE_INNER_TURRET_at_14': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_14': 1,
#  'red_TOP_LANE_BASE_TURRET_at_14': 1,
#  'red_BOT_LANE_INNER_TURRET_at_14': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_14': 1,
#  'red_BOT_LANE_BASE_TURRET_at_14': 1,
#  'blue_MID_LANE_INNER_TURRET_at_15': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_15': 1,
#  'blue_MID_LANE_BASE_TURRET_at_15': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_15': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_15': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_15': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_15': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_15': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_15': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_15': 1,
#  'red_MID_LANE_INNER_TURRET_at_15': 1,
#  'red_MID_LANE_OUTER_TURRET_at_15': 1,
#  'red_MID_LANE_BASE_TURRET_at_15': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_15': 2,
#  'red_TOP_LANE_INNER_TURRET_at_15': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_15': 0,
#  'red_TOP_LANE_BASE_TURRET_at_15': 1,
#  'red_BOT_LANE_INNER_TURRET_at_15': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_15': 1,
#  'red_BOT_LANE_BASE_TURRET_at_15': 1,
#  'blue_MID_LANE_INNER_TURRET_at_16': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_16': 1,
#  'blue_MID_LANE_BASE_TURRET_at_16': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_16': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_16': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_16': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_16': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_16': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_16': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_16': 1,
#  'red_MID_LANE_INNER_TURRET_at_16': 1,
#  'red_MID_LANE_OUTER_TURRET_at_16': 1,
#  'red_MID_LANE_BASE_TURRET_at_16': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_16': 2,
#  'red_TOP_LANE_INNER_TURRET_at_16': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_16': 0,
#  'red_TOP_LANE_BASE_TURRET_at_16': 1,
#  'red_BOT_LANE_INNER_TURRET_at_16': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_16': 1,
#  'red_BOT_LANE_BASE_TURRET_at_16': 1,
#  'blue_MID_LANE_INNER_TURRET_at_17': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_17': 1,
#  'blue_MID_LANE_BASE_TURRET_at_17': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_17': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_17': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_17': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_17': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_17': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_17': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_17': 1,
#  'red_MID_LANE_INNER_TURRET_at_17': 1,
#  'red_MID_LANE_OUTER_TURRET_at_17': 1,
#  'red_MID_LANE_BASE_TURRET_at_17': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_17': 2,
#  'red_TOP_LANE_INNER_TURRET_at_17': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_17': 0,
#  'red_TOP_LANE_BASE_TURRET_at_17': 1,
#  'red_BOT_LANE_INNER_TURRET_at_17': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_17': 1,
#  'red_BOT_LANE_BASE_TURRET_at_17': 1,
#  'blue_MID_LANE_INNER_TURRET_at_18': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_18': 1,
#  'blue_MID_LANE_BASE_TURRET_at_18': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_18': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_18': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_18': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_18': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_18': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_18': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_18': 1,
#  'red_MID_LANE_INNER_TURRET_at_18': 1,
#  'red_MID_LANE_OUTER_TURRET_at_18': 0,
#  'red_MID_LANE_BASE_TURRET_at_18': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_18': 2,
#  'red_TOP_LANE_INNER_TURRET_at_18': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_18': 0,
#  'red_TOP_LANE_BASE_TURRET_at_18': 1,
#  'red_BOT_LANE_INNER_TURRET_at_18': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_18': 1,
#  'red_BOT_LANE_BASE_TURRET_at_18': 1,
#  'blue_MID_LANE_INNER_TURRET_at_19': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_19': 1,
#  'blue_MID_LANE_BASE_TURRET_at_19': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_19': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_19': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_19': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_19': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_19': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_19': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_19': 1,
#  'red_MID_LANE_INNER_TURRET_at_19': 1,
#  'red_MID_LANE_OUTER_TURRET_at_19': 0,
#  'red_MID_LANE_BASE_TURRET_at_19': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_19': 2,
#  'red_TOP_LANE_INNER_TURRET_at_19': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_19': 0,
#  'red_TOP_LANE_BASE_TURRET_at_19': 1,
#  'red_BOT_LANE_INNER_TURRET_at_19': 1,
#  'red_BOT_LANE_OUTER_TURRET_at_19': 0,
#  'red_BOT_LANE_BASE_TURRET_at_19': 1,
#  'blue_MID_LANE_INNER_TURRET_at_20': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_20': 1,
#  'blue_MID_LANE_BASE_TURRET_at_20': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_20': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_20': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_20': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_20': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_20': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_20': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_20': 1,
#  'red_MID_LANE_INNER_TURRET_at_20': 1,
#  'red_MID_LANE_OUTER_TURRET_at_20': 0,
#  'red_MID_LANE_BASE_TURRET_at_20': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_20': 2,
#  'red_TOP_LANE_INNER_TURRET_at_20': 1,
#  'red_TOP_LANE_OUTER_TURRET_at_20': 0,
#  'red_TOP_LANE_BASE_TURRET_at_20': 1,
#  'red_BOT_LANE_INNER_TURRET_at_20': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_20': 0,
#  'red_BOT_LANE_BASE_TURRET_at_20': 1,
#  'blue_MID_LANE_INNER_TURRET_at_21': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_21': 0,
#  'blue_MID_LANE_BASE_TURRET_at_21': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_21': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_21': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_21': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_21': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_21': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_21': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_21': 1,
#  'red_MID_LANE_INNER_TURRET_at_21': 1,
#  'red_MID_LANE_OUTER_TURRET_at_21': 0,
#  'red_MID_LANE_BASE_TURRET_at_21': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_21': 2,
#  'red_TOP_LANE_INNER_TURRET_at_21': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_21': 0,
#  'red_TOP_LANE_BASE_TURRET_at_21': 1,
#  'red_BOT_LANE_INNER_TURRET_at_21': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_21': 0,
#  'red_BOT_LANE_BASE_TURRET_at_21': 1,
#  'blue_MID_LANE_INNER_TURRET_at_22': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_22': 0,
#  'blue_MID_LANE_BASE_TURRET_at_22': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_22': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_22': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_22': 1,
#  'blue_TOP_LANE_BASE_TURRET_at_22': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_22': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_22': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_22': 1,
#  'red_MID_LANE_INNER_TURRET_at_22': 1,
#  'red_MID_LANE_OUTER_TURRET_at_22': 0,
#  'red_MID_LANE_BASE_TURRET_at_22': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_22': 2,
#  'red_TOP_LANE_INNER_TURRET_at_22': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_22': 0,
#  'red_TOP_LANE_BASE_TURRET_at_22': 1,
#  'red_BOT_LANE_INNER_TURRET_at_22': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_22': 0,
#  'red_BOT_LANE_BASE_TURRET_at_22': 1,
#  'blue_MID_LANE_INNER_TURRET_at_23': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_23': 0,
#  'blue_MID_LANE_BASE_TURRET_at_23': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_23': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_23': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_23': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_23': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_23': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_23': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_23': 1,
#  'red_MID_LANE_INNER_TURRET_at_23': 1,
#  'red_MID_LANE_OUTER_TURRET_at_23': 0,
#  'red_MID_LANE_BASE_TURRET_at_23': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_23': 2,
#  'red_TOP_LANE_INNER_TURRET_at_23': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_23': 0,
#  'red_TOP_LANE_BASE_TURRET_at_23': 1,
#  'red_BOT_LANE_INNER_TURRET_at_23': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_23': 0,
#  'red_BOT_LANE_BASE_TURRET_at_23': 1,
#  'blue_MID_LANE_INNER_TURRET_at_24': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_24': 0,
#  'blue_MID_LANE_BASE_TURRET_at_24': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_24': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_24': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_24': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_24': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_24': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_24': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_24': 1,
#  'red_MID_LANE_INNER_TURRET_at_24': 1,
#  'red_MID_LANE_OUTER_TURRET_at_24': 0,
#  'red_MID_LANE_BASE_TURRET_at_24': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_24': 2,
#  'red_TOP_LANE_INNER_TURRET_at_24': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_24': 0,
#  'red_TOP_LANE_BASE_TURRET_at_24': 1,
#  'red_BOT_LANE_INNER_TURRET_at_24': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_24': 0,
#  'red_BOT_LANE_BASE_TURRET_at_24': 1,
#  'blue_MID_LANE_INNER_TURRET_at_25': 1,
#  'blue_MID_LANE_OUTER_TURRET_at_25': 0,
#  'blue_MID_LANE_BASE_TURRET_at_25': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_25': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_25': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_25': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_25': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_25': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_25': 1,
#  'blue_BOT_LANE_BASE_TURRET_at_25': 1,
#  'red_MID_LANE_INNER_TURRET_at_25': 1,
#  'red_MID_LANE_OUTER_TURRET_at_25': 0,
#  'red_MID_LANE_BASE_TURRET_at_25': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_25': 2,
#  'red_TOP_LANE_INNER_TURRET_at_25': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_25': 0,
#  'red_TOP_LANE_BASE_TURRET_at_25': 1,
#  'red_BOT_LANE_INNER_TURRET_at_25': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_25': 0,
#  'red_BOT_LANE_BASE_TURRET_at_25': 1,
#  'blue_MID_LANE_INNER_TURRET_at_26': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_26': 0,
#  'blue_MID_LANE_BASE_TURRET_at_26': 1,
#  'blue_MID_LANE_NEXUS_TURRET_at_26': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_26': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_26': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_26': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_26': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_26': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_26': 1,
#  'red_MID_LANE_INNER_TURRET_at_26': 1,
#  'red_MID_LANE_OUTER_TURRET_at_26': 0,
#  'red_MID_LANE_BASE_TURRET_at_26': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_26': 2,
#  'red_TOP_LANE_INNER_TURRET_at_26': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_26': 0,
#  'red_TOP_LANE_BASE_TURRET_at_26': 1,
#  'red_BOT_LANE_INNER_TURRET_at_26': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_26': 0,
#  'red_BOT_LANE_BASE_TURRET_at_26': 1,
#  'blue_MID_LANE_INNER_TURRET_at_27': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_27': 0,
#  'blue_MID_LANE_BASE_TURRET_at_27': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_27': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_27': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_27': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_27': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_27': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_27': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_27': 1,
#  'red_MID_LANE_INNER_TURRET_at_27': 1,
#  'red_MID_LANE_OUTER_TURRET_at_27': 0,
#  'red_MID_LANE_BASE_TURRET_at_27': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_27': 2,
#  'red_TOP_LANE_INNER_TURRET_at_27': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_27': 0,
#  'red_TOP_LANE_BASE_TURRET_at_27': 1,
#  'red_BOT_LANE_INNER_TURRET_at_27': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_27': 0,
#  'red_BOT_LANE_BASE_TURRET_at_27': 1,
#  'blue_MID_LANE_INNER_TURRET_at_28': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_28': 0,
#  'blue_MID_LANE_BASE_TURRET_at_28': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_28': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_28': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_28': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_28': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_28': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_28': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_28': 1,
#  'red_MID_LANE_INNER_TURRET_at_28': 1,
#  'red_MID_LANE_OUTER_TURRET_at_28': 0,
#  'red_MID_LANE_BASE_TURRET_at_28': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_28': 2,
#  'red_TOP_LANE_INNER_TURRET_at_28': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_28': 0,
#  'red_TOP_LANE_BASE_TURRET_at_28': 1,
#  'red_BOT_LANE_INNER_TURRET_at_28': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_28': 0,
#  'red_BOT_LANE_BASE_TURRET_at_28': 1,
#  'blue_MID_LANE_INNER_TURRET_at_29': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_29': 0,
#  'blue_MID_LANE_BASE_TURRET_at_29': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_29': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_29': 1,
#  'blue_TOP_LANE_OUTER_TURRET_at_29': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_29': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_29': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_29': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_29': 1,
#  'red_MID_LANE_INNER_TURRET_at_29': 1,
#  'red_MID_LANE_OUTER_TURRET_at_29': 0,
#  'red_MID_LANE_BASE_TURRET_at_29': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_29': 2,
#  'red_TOP_LANE_INNER_TURRET_at_29': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_29': 0,
#  'red_TOP_LANE_BASE_TURRET_at_29': 1,
#  'red_BOT_LANE_INNER_TURRET_at_29': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_29': 0,
#  'red_BOT_LANE_BASE_TURRET_at_29': 1,
#  'blue_MID_LANE_INNER_TURRET_at_30': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_30': 0,
#  'blue_MID_LANE_BASE_TURRET_at_30': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_30': 2,
#  'blue_TOP_LANE_INNER_TURRET_at_30': 0,
#  'blue_TOP_LANE_OUTER_TURRET_at_30': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_30': 1,
#  'blue_BOT_LANE_INNER_TURRET_at_30': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_30': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_30': 1,
#  'red_MID_LANE_INNER_TURRET_at_30': 1,
#  'red_MID_LANE_OUTER_TURRET_at_30': 0,
#  'red_MID_LANE_BASE_TURRET_at_30': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_30': 2,
#  'red_TOP_LANE_INNER_TURRET_at_30': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_30': 0,
#  'red_TOP_LANE_BASE_TURRET_at_30': 1,
#  'red_BOT_LANE_INNER_TURRET_at_30': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_30': 0,
#  'red_BOT_LANE_BASE_TURRET_at_30': 1,
#  'blue_MID_LANE_INNER_TURRET_at_31': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_31': 0,
#  'blue_MID_LANE_BASE_TURRET_at_31': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_31': 1,
#  'blue_TOP_LANE_INNER_TURRET_at_31': 0,
#  'blue_TOP_LANE_OUTER_TURRET_at_31': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_31': 0,
#  'blue_BOT_LANE_INNER_TURRET_at_31': 1,
#  'blue_BOT_LANE_OUTER_TURRET_at_31': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_31': 1,
#  'red_MID_LANE_INNER_TURRET_at_31': 1,
#  'red_MID_LANE_OUTER_TURRET_at_31': 0,
#  'red_MID_LANE_BASE_TURRET_at_31': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_31': 2,
#  'red_TOP_LANE_INNER_TURRET_at_31': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_31': 0,
#  'red_TOP_LANE_BASE_TURRET_at_31': 1,
#  'red_BOT_LANE_INNER_TURRET_at_31': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_31': 0,
#  'red_BOT_LANE_BASE_TURRET_at_31': 1,
#  'blue_MID_LANE_INNER_TURRET_at_32': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_32': 0,
#  'blue_MID_LANE_BASE_TURRET_at_32': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_32': 1,
#  'blue_TOP_LANE_INNER_TURRET_at_32': 0,
#  'blue_TOP_LANE_OUTER_TURRET_at_32': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_32': 0,
#  'blue_BOT_LANE_INNER_TURRET_at_32': 0,
#  'blue_BOT_LANE_OUTER_TURRET_at_32': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_32': 1,
#  'red_MID_LANE_INNER_TURRET_at_32': 1,
#  'red_MID_LANE_OUTER_TURRET_at_32': 0,
#  'red_MID_LANE_BASE_TURRET_at_32': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_32': 2,
#  'red_TOP_LANE_INNER_TURRET_at_32': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_32': 0,
#  'red_TOP_LANE_BASE_TURRET_at_32': 1,
#  'red_BOT_LANE_INNER_TURRET_at_32': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_32': 0,
#  'red_BOT_LANE_BASE_TURRET_at_32': 1,
#  'blue_MID_LANE_INNER_TURRET_at_33': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_33': 0,
#  'blue_MID_LANE_BASE_TURRET_at_33': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_33': 1,
#  'blue_TOP_LANE_INNER_TURRET_at_33': 0,
#  'blue_TOP_LANE_OUTER_TURRET_at_33': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_33': 0,
#  'blue_BOT_LANE_INNER_TURRET_at_33': 0,
#  'blue_BOT_LANE_OUTER_TURRET_at_33': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_33': 1,
#  'red_MID_LANE_INNER_TURRET_at_33': 1,
#  'red_MID_LANE_OUTER_TURRET_at_33': 0,
#  'red_MID_LANE_BASE_TURRET_at_33': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_33': 2,
#  'red_TOP_LANE_INNER_TURRET_at_33': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_33': 0,
#  'red_TOP_LANE_BASE_TURRET_at_33': 1,
#  'red_BOT_LANE_INNER_TURRET_at_33': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_33': 0,
#  'red_BOT_LANE_BASE_TURRET_at_33': 1,
#  'blue_MID_LANE_INNER_TURRET_at_34': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_34': 0,
#  'blue_MID_LANE_BASE_TURRET_at_34': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_34': 1,
#  'blue_TOP_LANE_INNER_TURRET_at_34': 0,
#  'blue_TOP_LANE_OUTER_TURRET_at_34': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_34': 0,
#  'blue_BOT_LANE_INNER_TURRET_at_34': 0,
#  'blue_BOT_LANE_OUTER_TURRET_at_34': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_34': 1,
#  'red_MID_LANE_INNER_TURRET_at_34': 1,
#  'red_MID_LANE_OUTER_TURRET_at_34': 0,
#  'red_MID_LANE_BASE_TURRET_at_34': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_34': 2,
#  'red_TOP_LANE_INNER_TURRET_at_34': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_34': 0,
#  'red_TOP_LANE_BASE_TURRET_at_34': 1,
#  'red_BOT_LANE_INNER_TURRET_at_34': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_34': 0,
#  'red_BOT_LANE_BASE_TURRET_at_34': 1,
#  'blue_MID_LANE_INNER_TURRET_at_35': 0,
#  'blue_MID_LANE_OUTER_TURRET_at_35': 0,
#  'blue_MID_LANE_BASE_TURRET_at_35': 0,
#  'blue_MID_LANE_NEXUS_TURRET_at_35': 0,
#  'blue_TOP_LANE_INNER_TURRET_at_35': 0,
#  'blue_TOP_LANE_OUTER_TURRET_at_35': 0,
#  'blue_TOP_LANE_BASE_TURRET_at_35': 0,
#  'blue_BOT_LANE_INNER_TURRET_at_35': 0,
#  'blue_BOT_LANE_OUTER_TURRET_at_35': 0,
#  'blue_BOT_LANE_BASE_TURRET_at_35': 0,
#  'red_MID_LANE_INNER_TURRET_at_35': 1,
#  'red_MID_LANE_OUTER_TURRET_at_35': 0,
#  'red_MID_LANE_BASE_TURRET_at_35': 1,
#  'red_MID_LANE_NEXUS_TURRET_at_35': 2,
#  'red_TOP_LANE_INNER_TURRET_at_35': 0,
#  'red_TOP_LANE_OUTER_TURRET_at_35': 0,
#  'red_TOP_LANE_BASE_TURRET_at_35': 1,
#  'red_BOT_LANE_INNER_TURRET_at_35': 0,
#  'red_BOT_LANE_OUTER_TURRET_at_35': 0,
#  'red_BOT_LANE_BASE_TURRET_at_35': 1}

# %% [markdown]
# ### 3. Chênh lệch cấp độ mỗi đường, mỗi phút

# %%
# Hàm tính chênh lệch cấp độ mỗi đường giữa xanh và đỏ mỗi phút
def calculate_level_difference_by_lane(data):
    # Lưu trữ chênh lệch cấp độ mỗi đường, mỗi phút
    level_diff = {}

    # Lấy danh sách các frame (tương ứng phút)
    frames = data.get("info", {}).get("frames", [])

    # Định nghĩa các participantId cho các đường
    lane_participants = {
        "TOP": [1, 6],
        "JUNGLE": [2, 7],
        "MID": [3, 8],
        "BOT": [4, 9],
        "SUPPORT": [5, 10]
    }

    # Duyệt qua từng frame (mỗi frame là 1 phút)
    for frame_index, frame in enumerate(frames):
        minute = frame_index
        blue_team_levels = []
        red_team_levels = []

        for participantFrameID, participantFrame in frame["participantFrames"].items():
            participant_id = participantFrame.get("participantId")
            level = participantFrame.get("level")
            # Xác định đội (100 = blue, 200 = red)
            if participant_id <= 5:  # Đội xanh
                blue_team_levels.append(level)
            else:  # Đội đỏ
                red_team_levels.append(level)

        # Lưu trữ cấp độ của các người chơi trong từng đường
        for lane, participants in lane_participants.items():
            key = f"level_difference_{lane}_at_{minute}"  # minute + 1 vì phút bắt đầu từ 0
            level_diff[key] = blue_team_levels[participants[0] - 1] - red_team_levels[participants[1] - 6]
    return level_diff

# %%
# Dict chênh lệch cấp độ mỗi đường, mỗi phút
level_difference_by_lane_df = calculate_level_difference_by_lane(data)
level_difference_by_lane_df
# Out:
# {'level_difference_TOP_at_0': 0,
#  'level_difference_JUNGLE_at_0': 0,
#  'level_difference_MID_at_0': 0,
#  'level_difference_BOT_at_0': 0,
#  'level_difference_SUPPORT_at_0': 0,
#  'level_difference_TOP_at_1': 0,
#  'level_difference_JUNGLE_at_1': 0,
#  'level_difference_MID_at_1': 0,
#  'level_difference_BOT_at_1': 0,
#  'level_difference_SUPPORT_at_1': 0,
#  'level_difference_TOP_at_2': 0,
#  'level_difference_JUNGLE_at_2': -1,
#  'level_difference_MID_at_2': 0,
#  'level_difference_BOT_at_2': 0,
#  'level_difference_SUPPORT_at_2': 0,
#  'level_difference_TOP_at_3': 0,
#  'level_difference_JUNGLE_at_3': -1,
#  'level_difference_MID_at_3': 1,
#  'level_difference_BOT_at_3': 0,
#  'level_difference_SUPPORT_at_3': 1,
#  'level_difference_TOP_at_4': 0,
#  'level_difference_JUNGLE_at_4': -1,
#  'level_difference_MID_at_4': 0,
#  'level_difference_BOT_at_4': 0,
#  'level_difference_SUPPORT_at_4': 2,
#  'level_difference_TOP_at_5': 0,
#  'level_difference_JUNGLE_at_5': 0,
#  'level_difference_MID_at_5': 0,
#  'level_difference_BOT_at_5': 0,
#  'level_difference_SUPPORT_at_5': 0,
#  'level_difference_TOP_at_6': -1,
#  'level_difference_JUNGLE_at_6': 0,
#  'level_difference_MID_at_6': 0,
#  'level_difference_BOT_at_6': 0,
#  'level_difference_SUPPORT_at_6': 1,
#  'level_difference_TOP_at_7': -1,
#  'level_difference_JUNGLE_at_7': -1,
#  'level_difference_MID_at_7': 0,
#  'level_difference_BOT_at_7': 0,
#  'level_difference_SUPPORT_at_7': 0,
#  'level_difference_TOP_at_8': 0,
#  'level_difference_JUNGLE_at_8': -1,
#  'level_difference_MID_at_8': 0,
#  'level_difference_BOT_at_8': 1,
#  'level_difference_SUPPORT_at_8': 1,
#  'level_difference_TOP_at_9': -1,
#  'level_difference_JUNGLE_at_9': 0,
#  'level_difference_MID_at_9': 0,
#  'level_difference_BOT_at_9': 0,
#  'level_difference_SUPPORT_at_9': 0,
#  'level_difference_TOP_at_10': 0,
#  'level_difference_JUNGLE_at_10': -1,
#  'level_difference_MID_at_10': 0,
#  'level_difference_BOT_at_10': 0,
#  'level_difference_SUPPORT_at_10': 1,
#  'level_difference_TOP_at_11': 0,
#  'level_difference_JUNGLE_at_11': 0,
#  'level_difference_MID_at_11': -1,
#  'level_difference_BOT_at_11': 1,
#  'level_difference_SUPPORT_at_11': 1,
#  'level_difference_TOP_at_12': 0,
#  'level_difference_JUNGLE_at_12': 0,
#  'level_difference_MID_at_12': 0,
#  'level_difference_BOT_at_12': 0,
#  'level_difference_SUPPORT_at_12': 0,
#  'level_difference_TOP_at_13': -1,
#  'level_difference_JUNGLE_at_13': -1,
#  'level_difference_MID_at_13': -1,
#  'level_difference_BOT_at_13': 0,
#  'level_difference_SUPPORT_at_13': 1,
#  'level_difference_TOP_at_14': 0,
#  'level_difference_JUNGLE_at_14': -1,
#  'level_difference_MID_at_14': 0,
#  'level_difference_BOT_at_14': 0,
#  'level_difference_SUPPORT_at_14': 1,
#  'level_difference_TOP_at_15': 0,
#  'level_difference_JUNGLE_at_15': -1,
#  'level_difference_MID_at_15': 0,
#  'level_difference_BOT_at_15': 1,
#  'level_difference_SUPPORT_at_15': 0,
#  'level_difference_TOP_at_16': 0,
#  'level_difference_JUNGLE_at_16': -1,
#  'level_difference_MID_at_16': 0,
#  'level_difference_BOT_at_16': 0,
#  'level_difference_SUPPORT_at_16': 0,
#  'level_difference_TOP_at_17': -1,
#  'level_difference_JUNGLE_at_17': -1,
#  'level_difference_MID_at_17': -1,
#  'level_difference_BOT_at_17': 1,
#  'level_difference_SUPPORT_at_17': 0,
#  'level_difference_TOP_at_18': -1,
#  'level_difference_JUNGLE_at_18': 0,
#  'level_difference_MID_at_18': 0,
#  'level_difference_BOT_at_18': 1,
#  'level_difference_SUPPORT_at_18': 1,
#  'level_difference_TOP_at_19': -1,
#  'level_difference_JUNGLE_at_19': 1,
#  'level_difference_MID_at_19': 0,
#  'level_difference_BOT_at_19': 2,
#  'level_difference_SUPPORT_at_19': 1,
#  'level_difference_TOP_at_20': -1,
#  'level_difference_JUNGLE_at_20': 0,
#  'level_difference_MID_at_20': 0,
#  'level_difference_BOT_at_20': 1,
#  'level_difference_SUPPORT_at_20': 0,
#  'level_difference_TOP_at_21': 0,
#  'level_difference_JUNGLE_at_21': -1,
#  'level_difference_MID_at_21': -1,
#  'level_difference_BOT_at_21': 1,
#  'level_difference_SUPPORT_at_21': 0,
#  'level_difference_TOP_at_22': -1,
#  'level_difference_JUNGLE_at_22': -1,
#  'level_difference_MID_at_22': 0,
#  'level_difference_BOT_at_22': 1,
#  'level_difference_SUPPORT_at_22': 0,
#  'level_difference_TOP_at_23': -1,
#  'level_difference_JUNGLE_at_23': -1,
#  'level_difference_MID_at_23': -1,
#  'level_difference_BOT_at_23': 1,
#  'level_difference_SUPPORT_at_23': 0,
#  'level_difference_TOP_at_24': 0,
#  'level_difference_JUNGLE_at_24': -1,
#  'level_difference_MID_at_24': 0,
#  'level_difference_BOT_at_24': 1,
#  'level_difference_SUPPORT_at_24': 0,
#  'level_difference_TOP_at_25': -1,
#  'level_difference_JUNGLE_at_25': -1,
#  'level_difference_MID_at_25': 0,
#  'level_difference_BOT_at_25': 2,
#  'level_difference_SUPPORT_at_25': 0,
#  'level_difference_TOP_at_26': -1,
#  'level_difference_JUNGLE_at_26': -1,
#  'level_difference_MID_at_26': -1,
#  'level_difference_BOT_at_26': 2,
#  'level_difference_SUPPORT_at_26': 0,
#  'level_difference_TOP_at_27': -2,
#  'level_difference_JUNGLE_at_27': -2,
#  'level_difference_MID_at_27': -1,
#  'level_difference_BOT_at_27': 1,
#  'level_difference_SUPPORT_at_27': 0,
#  'level_difference_TOP_at_28': -1,
#  'level_difference_JUNGLE_at_28': -2,
#  'level_difference_MID_at_28': -2,
#  'level_difference_BOT_at_28': 2,
#  'level_difference_SUPPORT_at_28': -1,
#  'level_difference_TOP_at_29': -2,
#  'level_difference_JUNGLE_at_29': -3,
#  'level_difference_MID_at_29': -2,
#  'level_difference_BOT_at_29': 1,
#  'level_difference_SUPPORT_at_29': -1,
#  'level_difference_TOP_at_30': -1,
#  'level_difference_JUNGLE_at_30': -3,
#  'level_difference_MID_at_30': -3,
#  'level_difference_BOT_at_30': 2,
#  'level_difference_SUPPORT_at_30': -1,
#  'level_difference_TOP_at_31': -1,
#  'level_difference_JUNGLE_at_31': -3,
#  'level_difference_MID_at_31': -2,
#  'level_difference_BOT_at_31': 2,
#  'level_difference_SUPPORT_at_31': -2,
#  'level_difference_TOP_at_32': -1,
#  'level_difference_JUNGLE_at_32': -2,
#  'level_difference_MID_at_32': -2,
#  'level_difference_BOT_at_32': 2,
#  'level_difference_SUPPORT_at_32': -1,
#  'level_difference_TOP_at_33': -1,
#  'level_difference_JUNGLE_at_33': -2,
#  'level_difference_MID_at_33': -2,
#  'level_difference_BOT_at_33': 2,
#  'level_difference_SUPPORT_at_33': -1,
#  'level_difference_TOP_at_34': -1,
#  'level_difference_JUNGLE_at_34': -3,
#  'level_difference_MID_at_34': -3,
#  'level_difference_BOT_at_34': 2,
#  'level_difference_SUPPORT_at_34': -1,
#  'level_difference_TOP_at_35': -1,
#  'level_difference_JUNGLE_at_35': -3,
#  'level_difference_MID_at_35': -3,
#  'level_difference_BOT_at_35': 1,
#  'level_difference_SUPPORT_at_35': -1}

# %% [markdown]
# ### 4. Trạng thái quái khủng, mỗi đội, mỗi phút

# %%
# Hàm tính chênh lệch quái khủng mỗi loại, mỗi phút giữa đội xanh và đỏ
def calculate_elite_monster_diff(data):
    initial_elite_monster_diff = {
        "HORDE": 0,
        "RIFTHERALD" : 0,
        "FIRE_DRAGON": 0,
        "WATER_DRAGON": 0,
        "EARTH_DRAGON": 0,
        "AIR_DRAGON": 0,
        "CHEMTECH_DRAGON": 0,
        "HEXTECH_DRAGON": 0,
        "ELDER_DRAGON": 0,
        "BARON_NASHOR" : 0
        
    }

    # Kết quả lưu trạng thái trụ theo từng phút
    elite_monster_status = {}

    # Lấy danh sách các frame (tương ứng phút)
    frames = data.get("info", {}).get("frames", [])

    # Duyệt qua từng frame (mỗi frame là 1 phút)
    for frame_index, frame in enumerate(frames):
        minute = frame_index

        for monster_type in initial_elite_monster_diff.keys():
            key = f"{monster_type}_diff_at_{minute}"
            elite_monster_status[key] = initial_elite_monster_diff[monster_type]

        # Lấy danh sách sự kiện trong frame
        events = frame.get("events", [])

        for event in events:
            # Kiểm tra nếu sự kiện là ăn quái
            if event.get("type") == "ELITE_MONSTER_KILL":
                team_id = event.get("killerTeamId")

                # Xác định đội (100 = blue, 200 = red)
                team = "blue" if team_id == 100 else "red"

                monster_type = event.get("monsterType", "")
                sub_monster_type = event.get("monsterSubType", "")

                if monster_type == "DRAGON":
                    if sub_monster_type:
                        key = f"{sub_monster_type}_diff_at_{minute}"
                        if team == "blue":
                            initial_elite_monster_diff[sub_monster_type] += 1
                        else:
                            initial_elite_monster_diff[sub_monster_type] -= 1
                        elite_monster_status[key] = initial_elite_monster_diff[sub_monster_type]
                else:
                    key = f"{monster_type}_diff_at_{minute}"
                    if team == "blue":
                        initial_elite_monster_diff[monster_type] += 1
                    else:
                        initial_elite_monster_diff[monster_type] -= 1
                    elite_monster_status[key] = initial_elite_monster_diff[monster_type]
    return elite_monster_status

# %%
# Dict chênh lệch quái khủng mỗi loại, mỗi phút giữa đội xanh và đỏ
elite_monster_diff = calculate_elite_monster_diff(data)
elite_monster_diff
# Out:
# {'HORDE_diff_at_0': 0,
#  'RIFTHERALD_diff_at_0': 0,
#  'FIRE_DRAGON_diff_at_0': 0,
#  'WATER_DRAGON_diff_at_0': 0,
#  'EARTH_DRAGON_diff_at_0': 0,
#  'AIR_DRAGON_diff_at_0': 0,
#  'CHEMTECH_DRAGON_diff_at_0': 0,
#  'HEXTECH_DRAGON_diff_at_0': 0,
#  'ELDER_DRAGON_diff_at_0': 0,
#  'BARON_NASHOR_diff_at_0': 0,
#  'HORDE_diff_at_1': 0,
#  'RIFTHERALD_diff_at_1': 0,
#  'FIRE_DRAGON_diff_at_1': 0,
#  'WATER_DRAGON_diff_at_1': 0,
#  'EARTH_DRAGON_diff_at_1': 0,
#  'AIR_DRAGON_diff_at_1': 0,
#  'CHEMTECH_DRAGON_diff_at_1': 0,
#  'HEXTECH_DRAGON_diff_at_1': 0,
#  'ELDER_DRAGON_diff_at_1': 0,
#  'BARON_NASHOR_diff_at_1': 0,
#  'HORDE_diff_at_2': 0,
#  'RIFTHERALD_diff_at_2': 0,
#  'FIRE_DRAGON_diff_at_2': 0,
#  'WATER_DRAGON_diff_at_2': 0,
#  'EARTH_DRAGON_diff_at_2': 0,
#  'AIR_DRAGON_diff_at_2': 0,
#  'CHEMTECH_DRAGON_diff_at_2': 0,
#  'HEXTECH_DRAGON_diff_at_2': 0,
#  'ELDER_DRAGON_diff_at_2': 0,
#  'BARON_NASHOR_diff_at_2': 0,
#  'HORDE_diff_at_3': 0,
#  'RIFTHERALD_diff_at_3': 0,
#  'FIRE_DRAGON_diff_at_3': 0,
#  'WATER_DRAGON_diff_at_3': 0,
#  'EARTH_DRAGON_diff_at_3': 0,
#  'AIR_DRAGON_diff_at_3': 0,
#  'CHEMTECH_DRAGON_diff_at_3': 0,
#  'HEXTECH_DRAGON_diff_at_3': 0,
#  'ELDER_DRAGON_diff_at_3': 0,
#  'BARON_NASHOR_diff_at_3': 0,
#  'HORDE_diff_at_4': 0,
#  'RIFTHERALD_diff_at_4': 0,
#  'FIRE_DRAGON_diff_at_4': 0,
#  'WATER_DRAGON_diff_at_4': 0,
#  'EARTH_DRAGON_diff_at_4': 0,
#  'AIR_DRAGON_diff_at_4': 0,
#  'CHEMTECH_DRAGON_diff_at_4': 0,
#  'HEXTECH_DRAGON_diff_at_4': 0,
#  'ELDER_DRAGON_diff_at_4': 0,
#  'BARON_NASHOR_diff_at_4': 0,
#  'HORDE_diff_at_5': 0,
#  'RIFTHERALD_diff_at_5': 0,
#  'FIRE_DRAGON_diff_at_5': 0,
#  'WATER_DRAGON_diff_at_5': 0,
#  'EARTH_DRAGON_diff_at_5': 0,
#  'AIR_DRAGON_diff_at_5': 0,
#  'CHEMTECH_DRAGON_diff_at_5': 0,
#  'HEXTECH_DRAGON_diff_at_5': 0,
#  'ELDER_DRAGON_diff_at_5': 0,
#  'BARON_NASHOR_diff_at_5': 0,
#  'HORDE_diff_at_6': 0,
#  'RIFTHERALD_diff_at_6': 0,
#  'FIRE_DRAGON_diff_at_6': 0,
#  'WATER_DRAGON_diff_at_6': 0,
#  'EARTH_DRAGON_diff_at_6': 0,
#  'AIR_DRAGON_diff_at_6': 0,
#  'CHEMTECH_DRAGON_diff_at_6': 0,
#  'HEXTECH_DRAGON_diff_at_6': 0,
#  'ELDER_DRAGON_diff_at_6': 0,
#  'BARON_NASHOR_diff_at_6': 0,
#  'HORDE_diff_at_7': 0,
#  'RIFTHERALD_diff_at_7': 0,
#  'FIRE_DRAGON_diff_at_7': 0,
#  'WATER_DRAGON_diff_at_7': 0,
#  'EARTH_DRAGON_diff_at_7': 0,
#  'AIR_DRAGON_diff_at_7': 0,
#  'CHEMTECH_DRAGON_diff_at_7': 0,
#  'HEXTECH_DRAGON_diff_at_7': 0,
#  'ELDER_DRAGON_diff_at_7': 0,
#  'BARON_NASHOR_diff_at_7': 0,
#  'HORDE_diff_at_8': -3,
#  'RIFTHERALD_diff_at_8': 0,
#  'FIRE_DRAGON_diff_at_8': 1,
#  'WATER_DRAGON_diff_at_8': 0,
#  'EARTH_DRAGON_diff_at_8': 0,
#  'AIR_DRAGON_diff_at_8': 0,
#  'CHEMTECH_DRAGON_diff_at_8': 0,
#  'HEXTECH_DRAGON_diff_at_8': 0,
#  'ELDER_DRAGON_diff_at_8': 0,
#  'BARON_NASHOR_diff_at_8': 0,
#  'HORDE_diff_at_9': -3,
#  'RIFTHERALD_diff_at_9': 0,
#  'FIRE_DRAGON_diff_at_9': 1,
#  'WATER_DRAGON_diff_at_9': 0,
#  'EARTH_DRAGON_diff_at_9': 0,
#  'AIR_DRAGON_diff_at_9': 0,
#  'CHEMTECH_DRAGON_diff_at_9': 0,
#  'HEXTECH_DRAGON_diff_at_9': 0,
#  'ELDER_DRAGON_diff_at_9': 0,
#  'BARON_NASHOR_diff_at_9': 0,
#  'HORDE_diff_at_10': -3,
#  'RIFTHERALD_diff_at_10': 0,
#  'FIRE_DRAGON_diff_at_10': 1,
#  'WATER_DRAGON_diff_at_10': 0,
#  'EARTH_DRAGON_diff_at_10': 0,
#  'AIR_DRAGON_diff_at_10': 0,
#  'CHEMTECH_DRAGON_diff_at_10': 0,
#  'HEXTECH_DRAGON_diff_at_10': 0,
#  'ELDER_DRAGON_diff_at_10': 0,
#  'BARON_NASHOR_diff_at_10': 0,
#  'HORDE_diff_at_11': -3,
#  'RIFTHERALD_diff_at_11': 0,
#  'FIRE_DRAGON_diff_at_11': 1,
#  'WATER_DRAGON_diff_at_11': 0,
#  'EARTH_DRAGON_diff_at_11': 0,
#  'AIR_DRAGON_diff_at_11': 0,
#  'CHEMTECH_DRAGON_diff_at_11': 0,
#  'HEXTECH_DRAGON_diff_at_11': 0,
#  'ELDER_DRAGON_diff_at_11': 0,
#  'BARON_NASHOR_diff_at_11': 0,
#  'HORDE_diff_at_12': -3,
#  'RIFTHERALD_diff_at_12': 0,
#  'FIRE_DRAGON_diff_at_12': 1,
#  'WATER_DRAGON_diff_at_12': 0,
#  'EARTH_DRAGON_diff_at_12': 0,
#  'AIR_DRAGON_diff_at_12': 0,
#  'CHEMTECH_DRAGON_diff_at_12': 0,
#  'HEXTECH_DRAGON_diff_at_12': 0,
#  'ELDER_DRAGON_diff_at_12': 0,
#  'BARON_NASHOR_diff_at_12': 0,
#  'HORDE_diff_at_13': -2,
#  'RIFTHERALD_diff_at_13': 0,
#  'FIRE_DRAGON_diff_at_13': 1,
#  'WATER_DRAGON_diff_at_13': 0,
#  'EARTH_DRAGON_diff_at_13': 0,
#  'AIR_DRAGON_diff_at_13': 0,
#  'CHEMTECH_DRAGON_diff_at_13': 0,
#  'HEXTECH_DRAGON_diff_at_13': 0,
#  'ELDER_DRAGON_diff_at_13': 0,
#  'BARON_NASHOR_diff_at_13': 0,
#  'HORDE_diff_at_14': -4,
#  'RIFTHERALD_diff_at_14': 0,
#  'FIRE_DRAGON_diff_at_14': 1,
#  'WATER_DRAGON_diff_at_14': 0,
#  'EARTH_DRAGON_diff_at_14': 0,
#  'AIR_DRAGON_diff_at_14': 0,
#  'CHEMTECH_DRAGON_diff_at_14': 0,
#  'HEXTECH_DRAGON_diff_at_14': 0,
#  'ELDER_DRAGON_diff_at_14': 0,
#  'BARON_NASHOR_diff_at_14': 0,
#  'HORDE_diff_at_15': -4,
#  'RIFTHERALD_diff_at_15': 0,
#  'FIRE_DRAGON_diff_at_15': 1,
#  'WATER_DRAGON_diff_at_15': 1,
#  'EARTH_DRAGON_diff_at_15': 0,
#  'AIR_DRAGON_diff_at_15': 0,
#  'CHEMTECH_DRAGON_diff_at_15': 0,
#  'HEXTECH_DRAGON_diff_at_15': 0,
#  'ELDER_DRAGON_diff_at_15': 0,
#  'BARON_NASHOR_diff_at_15': 0,
#  'HORDE_diff_at_16': -4,
#  'RIFTHERALD_diff_at_16': 0,
#  'FIRE_DRAGON_diff_at_16': 1,
#  'WATER_DRAGON_diff_at_16': 1,
#  'EARTH_DRAGON_diff_at_16': 0,
#  'AIR_DRAGON_diff_at_16': 0,
#  'CHEMTECH_DRAGON_diff_at_16': 0,
#  'HEXTECH_DRAGON_diff_at_16': 0,
#  'ELDER_DRAGON_diff_at_16': 0,
#  'BARON_NASHOR_diff_at_16': 0,
#  'HORDE_diff_at_17': -4,
#  'RIFTHERALD_diff_at_17': 1,
#  'FIRE_DRAGON_diff_at_17': 1,
#  'WATER_DRAGON_diff_at_17': 1,
#  'EARTH_DRAGON_diff_at_17': 0,
#  'AIR_DRAGON_diff_at_17': 0,
#  'CHEMTECH_DRAGON_diff_at_17': 0,
#  'HEXTECH_DRAGON_diff_at_17': 0,
#  'ELDER_DRAGON_diff_at_17': 0,
#  'BARON_NASHOR_diff_at_17': 0,
#  'HORDE_diff_at_18': -4,
#  'RIFTHERALD_diff_at_18': 1,
#  'FIRE_DRAGON_diff_at_18': 1,
#  'WATER_DRAGON_diff_at_18': 1,
#  'EARTH_DRAGON_diff_at_18': 0,
#  'AIR_DRAGON_diff_at_18': 0,
#  'CHEMTECH_DRAGON_diff_at_18': 0,
#  'HEXTECH_DRAGON_diff_at_18': 0,
#  'ELDER_DRAGON_diff_at_18': 0,
#  'BARON_NASHOR_diff_at_18': 0,
#  'HORDE_diff_at_19': -4,
#  'RIFTHERALD_diff_at_19': 1,
#  'FIRE_DRAGON_diff_at_19': 1,
#  'WATER_DRAGON_diff_at_19': 1,
#  'EARTH_DRAGON_diff_at_19': 0,
#  'AIR_DRAGON_diff_at_19': 0,
#  'CHEMTECH_DRAGON_diff_at_19': 0,
#  'HEXTECH_DRAGON_diff_at_19': 0,
#  'ELDER_DRAGON_diff_at_19': 0,
#  'BARON_NASHOR_diff_at_19': 0,
#  'HORDE_diff_at_20': -4,
#  'RIFTHERALD_diff_at_20': 1,
#  'FIRE_DRAGON_diff_at_20': 1,
#  'WATER_DRAGON_diff_at_20': 1,
#  'EARTH_DRAGON_diff_at_20': 0,
#  'AIR_DRAGON_diff_at_20': 0,
#  'CHEMTECH_DRAGON_diff_at_20': 0,
#  'HEXTECH_DRAGON_diff_at_20': 0,
#  'ELDER_DRAGON_diff_at_20': 0,
#  'BARON_NASHOR_diff_at_20': 0,
#  'HORDE_diff_at_21': -4,
#  'RIFTHERALD_diff_at_21': 1,
#  'FIRE_DRAGON_diff_at_21': 1,
#  'WATER_DRAGON_diff_at_21': 1,
#  'EARTH_DRAGON_diff_at_21': 0,
#  'AIR_DRAGON_diff_at_21': 0,
#  'CHEMTECH_DRAGON_diff_at_21': 0,
#  'HEXTECH_DRAGON_diff_at_21': -1,
#  'ELDER_DRAGON_diff_at_21': 0,
#  'BARON_NASHOR_diff_at_21': 0,
#  'HORDE_diff_at_22': -4,
#  'RIFTHERALD_diff_at_22': 1,
#  'FIRE_DRAGON_diff_at_22': 1,
#  'WATER_DRAGON_diff_at_22': 1,
#  'EARTH_DRAGON_diff_at_22': 0,
#  'AIR_DRAGON_diff_at_22': 0,
#  'CHEMTECH_DRAGON_diff_at_22': 0,
#  'HEXTECH_DRAGON_diff_at_22': -1,
#  'ELDER_DRAGON_diff_at_22': 0,
#  'BARON_NASHOR_diff_at_22': 0,
#  'HORDE_diff_at_23': -4,
#  'RIFTHERALD_diff_at_23': 1,
#  'FIRE_DRAGON_diff_at_23': 1,
#  'WATER_DRAGON_diff_at_23': 1,
#  'EARTH_DRAGON_diff_at_23': 0,
#  'AIR_DRAGON_diff_at_23': 0,
#  'CHEMTECH_DRAGON_diff_at_23': 0,
#  'HEXTECH_DRAGON_diff_at_23': -1,
#  'ELDER_DRAGON_diff_at_23': 0,
#  'BARON_NASHOR_diff_at_23': 1,
#  'HORDE_diff_at_24': -4,
#  'RIFTHERALD_diff_at_24': 1,
#  'FIRE_DRAGON_diff_at_24': 1,
#  'WATER_DRAGON_diff_at_24': 1,
#  'EARTH_DRAGON_diff_at_24': 0,
#  'AIR_DRAGON_diff_at_24': 0,
#  'CHEMTECH_DRAGON_diff_at_24': 0,
#  'HEXTECH_DRAGON_diff_at_24': -1,
#  'ELDER_DRAGON_diff_at_24': 0,
#  'BARON_NASHOR_diff_at_24': 1,
#  'HORDE_diff_at_25': -4,
#  'RIFTHERALD_diff_at_25': 1,
#  'FIRE_DRAGON_diff_at_25': 1,
#  'WATER_DRAGON_diff_at_25': 1,
#  'EARTH_DRAGON_diff_at_25': 0,
#  'AIR_DRAGON_diff_at_25': 0,
#  'CHEMTECH_DRAGON_diff_at_25': 0,
#  'HEXTECH_DRAGON_diff_at_25': -1,
#  'ELDER_DRAGON_diff_at_25': 0,
#  'BARON_NASHOR_diff_at_25': 1,
#  'HORDE_diff_at_26': -4,
#  'RIFTHERALD_diff_at_26': 1,
#  'FIRE_DRAGON_diff_at_26': 1,
#  'WATER_DRAGON_diff_at_26': 1,
#  'EARTH_DRAGON_diff_at_26': 0,
#  'AIR_DRAGON_diff_at_26': 0,
#  'CHEMTECH_DRAGON_diff_at_26': 0,
#  'HEXTECH_DRAGON_diff_at_26': -1,
#  'ELDER_DRAGON_diff_at_26': 0,
#  'BARON_NASHOR_diff_at_26': 1,
#  'HORDE_diff_at_27': -4,
#  'RIFTHERALD_diff_at_27': 1,
#  'FIRE_DRAGON_diff_at_27': 1,
#  'WATER_DRAGON_diff_at_27': 1,
#  'EARTH_DRAGON_diff_at_27': 0,
#  'AIR_DRAGON_diff_at_27': 0,
#  'CHEMTECH_DRAGON_diff_at_27': 0,
#  'HEXTECH_DRAGON_diff_at_27': -2,
#  'ELDER_DRAGON_diff_at_27': 0,
#  'BARON_NASHOR_diff_at_27': 1,
#  'HORDE_diff_at_28': -4,
#  'RIFTHERALD_diff_at_28': 1,
#  'FIRE_DRAGON_diff_at_28': 1,
#  'WATER_DRAGON_diff_at_28': 1,
#  'EARTH_DRAGON_diff_at_28': 0,
#  'AIR_DRAGON_diff_at_28': 0,
#  'CHEMTECH_DRAGON_diff_at_28': 0,
#  'HEXTECH_DRAGON_diff_at_28': -2,
#  'ELDER_DRAGON_diff_at_28': 0,
#  'BARON_NASHOR_diff_at_28': 1,
#  'HORDE_diff_at_29': -4,
#  'RIFTHERALD_diff_at_29': 1,
#  'FIRE_DRAGON_diff_at_29': 1,
#  'WATER_DRAGON_diff_at_29': 1,
#  'EARTH_DRAGON_diff_at_29': 0,
#  'AIR_DRAGON_diff_at_29': 0,
#  'CHEMTECH_DRAGON_diff_at_29': 0,
#  'HEXTECH_DRAGON_diff_at_29': -2,
#  'ELDER_DRAGON_diff_at_29': 0,
#  'BARON_NASHOR_diff_at_29': 0,
#  'HORDE_diff_at_30': -4,
#  'RIFTHERALD_diff_at_30': 1,
#  'FIRE_DRAGON_diff_at_30': 1,
#  'WATER_DRAGON_diff_at_30': 1,
#  'EARTH_DRAGON_diff_at_30': 0,
#  'AIR_DRAGON_diff_at_30': 0,
#  'CHEMTECH_DRAGON_diff_at_30': 0,
#  'HEXTECH_DRAGON_diff_at_30': -2,
#  'ELDER_DRAGON_diff_at_30': 0,
#  'BARON_NASHOR_diff_at_30': 0,
#  'HORDE_diff_at_31': -4,
#  'RIFTHERALD_diff_at_31': 1,
#  'FIRE_DRAGON_diff_at_31': 1,
#  'WATER_DRAGON_diff_at_31': 1,
#  'EARTH_DRAGON_diff_at_31': 0,
#  'AIR_DRAGON_diff_at_31': 0,
#  'CHEMTECH_DRAGON_diff_at_31': 0,
#  'HEXTECH_DRAGON_diff_at_31': -2,
#  'ELDER_DRAGON_diff_at_31': 0,
#  'BARON_NASHOR_diff_at_31': 0,
#  'HORDE_diff_at_32': -4,
#  'RIFTHERALD_diff_at_32': 1,
#  'FIRE_DRAGON_diff_at_32': 1,
#  'WATER_DRAGON_diff_at_32': 1,
#  'EARTH_DRAGON_diff_at_32': 0,
#  'AIR_DRAGON_diff_at_32': 0,
#  'CHEMTECH_DRAGON_diff_at_32': 0,
#  'HEXTECH_DRAGON_diff_at_32': -2,
#  'ELDER_DRAGON_diff_at_32': 0,
#  'BARON_NASHOR_diff_at_32': 0,
#  'HORDE_diff_at_33': -4,
#  'RIFTHERALD_diff_at_33': 1,
#  'FIRE_DRAGON_diff_at_33': 1,
#  'WATER_DRAGON_diff_at_33': 1,
#  'EARTH_DRAGON_diff_at_33': 0,
#  'AIR_DRAGON_diff_at_33': 0,
#  'CHEMTECH_DRAGON_diff_at_33': 0,
#  'HEXTECH_DRAGON_diff_at_33': -3,
#  'ELDER_DRAGON_diff_at_33': 0,
#  'BARON_NASHOR_diff_at_33': 0,
#  'HORDE_diff_at_34': -4,
#  'RIFTHERALD_diff_at_34': 1,
#  'FIRE_DRAGON_diff_at_34': 1,
#  'WATER_DRAGON_diff_at_34': 1,
#  'EARTH_DRAGON_diff_at_34': 0,
#  'AIR_DRAGON_diff_at_34': 0,
#  'CHEMTECH_DRAGON_diff_at_34': 0,
#  'HEXTECH_DRAGON_diff_at_34': -3,
#  'ELDER_DRAGON_diff_at_34': 0,
#  'BARON_NASHOR_diff_at_34': 0,
#  'HORDE_diff_at_35': -4,
#  'RIFTHERALD_diff_at_35': 1,
#  'FIRE_DRAGON_diff_at_35': 1,
#  'WATER_DRAGON_diff_at_35': 1,
#  'EARTH_DRAGON_diff_at_35': 0,
#  'AIR_DRAGON_diff_at_35': 0,
#  'CHEMTECH_DRAGON_diff_at_35': 0,
#  'HEXTECH_DRAGON_diff_at_35': -3,
#  'ELDER_DRAGON_diff_at_35': 0,
#  'BARON_NASHOR_diff_at_35': 0}

# %% [markdown]
# ### Làm sạch dữ liệu

# %%
def clean_df(df : pd.DataFrame):
    df = df.drop(columns=['metadata_dataVersion'] 
                + [col for col in df.columns if col.startswith('metadata_participants')]
                + [col for col in df.columns if col.startswith('info_participants')]
                )
    return df
